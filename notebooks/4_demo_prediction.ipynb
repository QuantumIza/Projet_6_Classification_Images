# %%
# ---------------------------
# --- MONTER LE GOOGLE DRIVE
# ---------------------------
from google.colab import drive
drive.mount('/content/drive')
# ----------------------------------
# --- AJOUT DE SRC DANS LE SYS PATH
# ----------------------------------
import sys
sys.path.append('/content/drive/MyDrive/Projet_6_Classification_Images/src')
# ------------------------------------------------------------------------------
# --- INITIALISATION ENVIRONNEMENT GRACE AU SCRIPT PYTHON setup_env.py DANS SRC
# ------------------------------------------------------------------------------
from setup_env import initialize_environment
initialize_environment()
# ----------------------------------------
# --- VERIFICATION VERSIONS INSTALLEES
# ----------------------------------------
import tensorflow as tf
import sklearn
import pandas as pd
import matplotlib
import numpy as np

print("TensorFlow:", tf.__version__)
print("scikit-learn:", sklearn.__version__)
print("pandas:", pd.__version__)
print("matplotlib:", matplotlib.__version__)
print("numpy:", np.__version__)
# Out:
# Mounted at /content/drive
# 📦 Installation des dépendances...
# 📂 Dossier src déjà dans le path.
# ✅ TensorFlow: 2.19.0
# ✅ scikit-learn: 1.6.1
# ✅ pandas: 2.2.2
# ✅ matplotlib: 3.10.0
# ✅ numpy: 2.0.2
# TensorFlow: 2.19.0
# scikit-learn: 1.6.1
# pandas: 2.2.2
# matplotlib: 3.10.0
# numpy: 2.0.2
